# %% [markdown]
# ## 1) Deps setup

# %%
# %pip install "feast[spark,aws]" xgboost
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: feast[aws,spark] in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (0.27.0)
# Requirement already satisfied: xgboost in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (1.7.1)
# Requirement already satisfied: PyYAML&lt;7,&gt;=5.4.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (6.0)
# Requirement already satisfied: SQLAlchemy[mypy]&lt;2,&gt;1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.4.44)
# Requirement already satisfied: dill==0.3.* in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (0.3.0)
# Requirement already satisfied: fastapi&lt;1,&gt;=0.68.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (0.88.0)
# Requirement already satisfied: click&lt;9.0.0,&gt;=7.0.0 in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (8.1.3)
# Requirement already satisfied: pandas&lt;2,&gt;=1.4.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.5.2)
# Requirement already satisfied: typeguard in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (2.13.3)
# Requirement already satisfied: proto-plus&lt;2,&gt;=1.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.22.1)
# Requirement already satisfied: tqdm&lt;5,&gt;=4 in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (4.64.1)
# Requirement already satisfied: google-api-core&lt;3,&gt;=1.23.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (2.11.0)
# Requirement already satisfied: pygments&lt;3,&gt;=2.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (2.13.0)
# Requirement already satisfied: pydantic&lt;2,&gt;=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.10.2)
# Requirement already satisfied: jsonschema in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (3.2.0)
# Requirement already satisfied: grpcio&lt;2,&gt;=1.47.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.51.1)
# Requirement already satisfied: fastavro&lt;2,&gt;=1.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.7.0)
# Requirement already satisfied: tabulate&lt;1,&gt;=0.8.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (0.9.0)
# Requirement already satisfied: grpcio-reflection&lt;2,&gt;=1.47.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.51.1)
# Requirement already satisfied: protobuf&lt;5,&gt;3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (4.21.10)
# Requirement already satisfied: tenacity&lt;9,&gt;=7 in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (8.0.1)
# Requirement already satisfied: pyarrow&lt;9,&gt;=4 in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (8.0.0)
# Requirement already satisfied: bowler in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (0.9.0)
# Requirement already satisfied: numpy&lt;3,&gt;=1.22 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.22.4)
# Requirement already satisfied: colorama&lt;1,&gt;=0.3.9 in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (0.4.6)
# Requirement already satisfied: toml&lt;1,&gt;=0.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (0.10.2)
# Requirement already satisfied: mmh3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (3.0.0)
# Requirement already satisfied: uvicorn[standard]&lt;1,&gt;=0.14.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (0.20.0)
# Requirement already satisfied: googleapis-common-protos&lt;2,&gt;=1.52.* in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (1.57.0)
# Requirement already satisfied: Jinja2&lt;4,&gt;=2 in /databricks/python3/lib/python3.8/site-packages (from feast[aws,spark]) (3.0.3)
# Requirement already satisfied: pandavro==1.5.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.5.2)
# Requirement already satisfied: dask&gt;=2021.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (2022.1.1)
# Requirement already satisfied: pyspark&lt;4,&gt;=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (3.3.1)
# Requirement already satisfied: docker&gt;=5.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (6.0.1)
# Requirement already satisfied: boto3&lt;=1.20.23,&gt;=1.17.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (1.20.23)
# Requirement already satisfied: s3fs&lt;=2022.01.0,&gt;=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from feast[aws,spark]) (2022.1.0)
# Requirement already satisfied: six&gt;=1.9 in /databricks/python3/lib/python3.8/site-packages (from pandavro==1.5.*-&gt;feast[aws,spark]) (1.15.0)
# Requirement already satisfied: botocore&lt;1.24.0,&gt;=1.23.23 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from boto3&lt;=1.20.23,&gt;=1.17.0-&gt;feast[aws,spark]) (1.23.24)
# Requirement already satisfied: jmespath&lt;1.0.0,&gt;=0.7.1 in /databricks/python3/lib/python3.8/site-packages (from boto3&lt;=1.20.23,&gt;=1.17.0-&gt;feast[aws,spark]) (0.10.0)
# Requirement already satisfied: s3transfer&lt;0.6.0,&gt;=0.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from boto3&lt;=1.20.23,&gt;=1.17.0-&gt;feast[aws,spark]) (0.5.2)
# Requirement already satisfied: python-dateutil&lt;3.0.0,&gt;=2.1 in /databricks/python3/lib/python3.8/site-packages (from botocore&lt;1.24.0,&gt;=1.23.23-&gt;boto3&lt;=1.20.23,&gt;=1.17.0-&gt;feast[aws,spark]) (2.8.1)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.25.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e93deaec-81cd-4c49-99b1-2308ee6f14f7/lib/python3.8/site-packages (from botocore

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import StructType, IntegerType, DoubleType, TimestampType

import pandas as pd
import os
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 2) EDA

# %%
books = spark.read.parquet("s3://tecton-demo-data/apply-book-recsys/books.parquet")
users = spark.read.parquet("s3://tecton-demo-data/apply-book-recsys/users.parquet")
ratings = spark.read.parquet("s3://tecton-demo-data/apply-book-recsys/ratings.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
-- CREATE DATABASE book_recsys_apply
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# books.write.mode("overwrite").saveAsTable("book_recsys_apply.books")
# users.write.mode("overwrite").saveAsTable("book_recsys_apply.users")
# ratings.write.mode("overwrite").saveAsTable("book_recsys_apply.ratings")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user_id: long (nullable = true)
# -- location: string (nullable = true)
# -- age: double (nullable = true)
# -- city: string (nullable = true)
# -- state: string (nullable = true)
# -- country: string (nullable = true)
# -- signup_date: timestamp (nullable = true)
# -- __index_level_0__: long (nullable = true)
#
# </div>

# %%
books.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- isbn: string (nullable = true)
# -- book_title: string (nullable = true)
# -- book_author: string (nullable = true)
# -- year_of_publication: integer (nullable = true)
# -- publisher: string (nullable = true)
# -- Summary: string (nullable = true)
# -- Language: string (nullable = true)
# -- Category: string (nullable = true)
# -- created_at: timestamp (nullable = true)
# -- __index_level_0__: long (nullable = true)
#
# </div>

# %%
display(users.groupby("country").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>count</th></tr></thead><tbody><tr><td>thailand"</td><td>1</td></tr><tr><td>guernsey</td><td>3</td></tr><tr><td>aruba</td><td>3</td></tr><tr><td>usa (currently living in england)</td><td>1</td></tr><tr><td>north sumatera, indonesia</td><td>1</td></tr><tr><td>finland</td><td>158</td></tr><tr><td>china"</td><td>1</td></tr><tr><td>australia</td><td>2672</td></tr><tr><td>greece</td><td>41</td></tr><tr><td>wales, united kingdom</td><td>2</td></tr><tr><td>portugal</td><td>456</td></tr><tr><td>tasmania, australia</td><td>1</td></tr><tr><td>kalamazoo, usa</td><td>1</td></tr><tr><td>israel</td><td
td>6</td></tr><tr><td>new zealand</td><td>693</td></tr><tr><td>washington, usa</td><td>3</td></tr><tr><td>travelling...., british columbia, canada</td><td>1</td></tr><tr><td>switzerland</td><td>623</td></tr><tr><td>rwanda</td><td>2</td></tr><tr><td>luxembourg</td><td>36</td></tr><tr><td>moldova</td><td>2</td></tr><tr><td>thailand</td><td>8</td></tr><tr><td>colombia</td><td>8</td></tr><tr><td>unknown</td><td>1</td></tr><tr><td>nsw, australia</td><td>1</td></tr><tr><td>a ...

# %%
display(books)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>isbn</th><th>book_title</th><th>book_author</th><th>year_of_publication</th><th>publisher</th><th>Summary</th><th>Language</th><th>Category</th><th>created_at</th><th>__index_level_0__</th></tr></thead><tbody><tr><td>0000913154</td><td>The Way Things Work: An Illustrated Encyclopedia of Technology</td><td>C. van Amerongen (translator)</td><td>1967</td><td>Simon & Schuster</td><td>Scientific principles, inventions, and chemical, mechanical, and
# industrial processes are explained for the general reader with the
# help of drawings and diagrams</td><td>en</td><td>Technology & Engineering</td><td>1967-01-01T12:00:00.000+0000</td><td>948518</td></tr><tr><td>0001055607</td><td>Cereus Blooms At Night</td><td>Shani Mootoo</td><td>1994</td><td>Fairmount Books Ltd Remainders</td><td>When Mala, old and notoriously crazy, arrives at the Paradise Alms
# House, she is placed in the tender care of Tyler, a gay male nurse,
# and an extraordinary relationship begins to develop.</td><td>en</td><td>Adult child abuse victims</td><td>1994-01-01T12:00:00.000+0000</td><td>826650</td></tr><tr><td>0001061127</td><td>CHESS FOR YOUNG BEGINNERS</td><td>William T. McLeod</td><td>1975</td><td>HarperCollins Publishers</td><td>A step by step guide to playing chess</td><td>en</td><td>Chess</td><td>1975-01-01T12:00:00.000+0000</td><td>908526</td></tr><tr><td>0001374362</td><td>When It's Time for Bed (Collins Baby & Toddler S.)</td><td>Nick Butterworth</td><td>1994</td><td>Collins</td><td>Shows baby and his animal friends preparing for bedtime. 1-2 yrs.</td><td>en</td><td>Animals</td><td>1994-01-01T12:00:00.000+0000</td><td>1025127</td></tr><tr><td>0001711253</td><td>The Big Honey Hunt</td><td>Stan Berenstein</td><td>1942</td><td>HarperCollins Publishers</td><td>Father Bear takes Small Bear on a honey hunt. After many problems,
# they go to their local store.</td><td>en</td><td>Bears</td><td>1942-01-01T12:00:00.000+0000</td><td>935227</td></tr><tr><td>000171421X</td><td>It's Not Easy Being a Bunny (A Beginner Book)</td><td>Marilyn Sadler</td><td>1984</td><td>HarperCollins Publishers</td><td>P.J. Funnybunny did not like being a bunny.</td><td>en</td><td>Animals</td><td>1984-01-01T12:00:00.000+0000</td><td>1028471</td></tr><tr><td>000184251X</td><td>February's Road</td><td>John Verney</td><td>1987</td><td>HarperCollins Publishers</td><td>The new road is to go right through the Callendar family&#39;s garden
# and February Callendar, while trying to change the Ministry&#39;s
# plans, discovers some very fishy things going on.</td><td>en</td><td>Children's stories, English</td><td>1987-01-01T12:00:00.000+0000</td><td>907750</td></tr><tr><td>0001850121</td><td>A place called Lantern Light</td><td>Ellen Miller</td><td>1975</td><td>Collins</td><td>They were nearing the end of their long journey.</td><td>en</td><td>Children's stories</td><td>1975-01-01T12:00:00.000+0000</td><td>917054</td></tr><tr><td>0001856367</td><td>The Collins Book of Ballet and Dance</td><td>Jean Ure</td><td>1996</td><td>HarperCollins Publishers</td><td>A collection of short stories about young people dedicated to the
></tr><tr><td>Diaries</td></tr><tr><td>Creative writing</td></tr><tr><td>Sweden</td></tr><tr><td>Elections</td></tr><tr><td>IBM-compatible computers</td></tr><tr><td>Newborn infants</td></tr><tr><td>Country life</td></tr><tr><td>High school students</td></tr><tr><td>Toronto (Ont.)</td></tr><tr><td>Computer software industry</td></tr><tr><td>Comedians</td></tr><tr><td>Human beings</td></tr><tr><td>Quiller (Fictitious character)</td></tr><tr><td>Horror tales</td></tr><tr><td>Hatha yoga</td></tr><tr><td>Body image</td></tr><tr><td>Bronx (New York, N.Y.)</td></tr><tr><td>Burma</td></tr><tr><td>College readers</td></tr><tr><td>Children's poetry</td></tr><tr><td>Marketing research</td></tr><tr><td>Comics & Graphic Novels</td></tr><tr><td>Creative ability</td></tr><tr><td>Griffins</td></tr><tr><td>Electricity</td></tr><tr><td>Literature, Modern</td></tr><tr><td>Science</td></tr><tr><td>Children and adults</td></tr><tr><td>Dinosaurs</td></tr><tr><td>Econometrics</td></tr><tr><td>Control de calidad</td></tr><tr><td>Annuals</td></tr><tr><td>Opéra</td></tr><tr><td>Latin language</td></tr><tr><td>Personnel management</td></tr><tr><td>Divorced women</td></tr><tr><td>Intellect</td></tr><tr><td>Country homes</td></tr><tr><td>Owls</td></tr><tr><td>English poetry</td></tr><tr><td>Atlases</td></tr><tr><td>Cold War</td></tr><tr><td>African American teenagers</td></tr><tr><td>Food</td></tr><tr><td>Mothers</td></tr><tr><td>Arrhythmia</td></tr><tr><td>Indians of North America.</td></tr><tr><td>Children's stories</td></tr><tr><td>Alleyn, Roderick (Fictitious character)</td></tr><tr><td>Chickens</td></tr><tr><td>Liberalism (Religion)</td></tr><tr><td>Current Events</td></tr><tr><td>Rodeos</td></tr><tr><td>Bankruptcy</td></tr><tr><td>Behavior</td></tr><tr><td>Artificial intelligence</td></tr><tr><td>Memory</td></tr><tr><td>Repairing</td></tr><tr><td>Grandfathers</td></tr><tr><td>Computer Industry - United States</td></tr><tr><td>Free trade</td></tr><tr><td>Europe</td></tr><tr><td>Good and evil</td></tr><tr><td>Sailors</td></tr><tr><td>Gunsmithing</td></tr><tr><td>Veterinarians</td></tr><tr><td>Germany</td></tr><tr><td>Expatriation</td></tr><tr><td> ...

# %%
display(books.select("Language").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Language</th></tr></thead><tbody><tr><td>en</td></tr><tr><td>vi</td></tr><tr><td>ro</td></tr><tr><td>pl</td></tr><tr><td>pt</td></tr><tr><td>tl</td></tr><tr><td>gl</td></tr><tr><td>ko</td></tr><tr><td>ms</td></tr><tr><td>de</td></tr><tr><td>es</td></tr><tr><td>el</td></tr><tr><td>it</td></tr><tr><td>ar</td></tr><tr><td>nl</td></tr><tr><td>zh-CN</td></tr><tr><td>ca</td></tr><tr><td>ru</td></tr><tr><td>th</td></tr><tr><td>ga</td></tr><tr><td>no</td></tr><tr><td>fa</td></tr><tr><td>cy</td></tr><tr><td>hi</td></tr><tr><td>eo</td></tr><tr><td>fr</td></tr><tr><td>ja</td></tr><tr><td>gd</td></tr><tr><td>la</td></tr><tr><td>zh-TW</td></tr><tr><td>da</td></tr></tbody></table></div>

# %% [markdown]
# ## 3) Init Feast Object

# %%
from feast import FeatureStore, RepoConfig
from feast.repo_config import RegistryConfig
from feast.infra.online_stores.dynamodb import DynamoDBOnlineStoreConfig
from feast.infra.offline_stores.contrib.spark_offline_store.spark import SparkOfflineStoreConfig
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=RuntimeWarning) 

repo_config = RepoConfig(
    registry="s3://[INSERT YOUR BUCKET]/feast-registry.db",
    project="feast_repo",
    provider="aws",
    offline_store=SparkOfflineStoreConfig(
      spark_conf={
        "spark.ui.enabled": "false",
        "spark.eventLog.enabled": "false",
        "spark.sql.catalogImplementation": "hive",
        "spark.sql.parser.quotedRegexColumnNames": "true",
        "spark.sql.session.timeZone": "UTC"
      }
    ),
    batch_engine={
      "type": "spark.engine",
      "partitions": 10
    },
    online_store=DynamoDBOnlineStoreConfig(region="us-west-1"),
    entity_key_serialization_version=2
)
store = FeatureStore(config=repo_config)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 4) Create upstream transformations (some of which go into dbt)

# %%
from pyspark.ml.feature import StringIndexer

# Feature #0: Last n in vanilla Spark doesn't work without custom aggregation state
# Feature #1: Encode user country (indexer is used after Feast)
stringIndexer = StringIndexer(
  inputCol="country", 
  outputCol="country_idx", 
  stringOrderType="frequencyDesc"
)
stringIndexer.setHandleInvalid("keep")
userCountryIndexerModel = stringIndexer.fit(users)
display(userCountryIndexerModel.transform(users))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>location</th><th>age</th><th>city</th><th>state</th><th>country</th><th>signup_date</th><th>__index_level_0__</th><th>country_idx</th></tr></thead><tbody><tr><td>2</td><td>stockton, california, usa</td><td>18.0</td><td>stockton</td><td>california</td><td>usa</td><td>2021-09-12T06:14:27.197+0000</td><td>0</td><td>0.0</td></tr><tr><td>8</td><td>timmins, ontario, canada</td><td>34.74389988072476</td><td>timmins</td><td>ontario</td><td>canada</td><td>2020-02-10T07:22:09.616+0000</td><td>3</td><td>1.0</td></tr><tr><td>9</td><td>germantown, tennessee, usa</td><td>34.74389988072476</td><td>germantown</td><td>tennessee</td><td>usa</td><td>2020-04-01T12:05:52.654+0000</td><td>32775</td><td>0.0</td></tr><tr><td>10</td><td>albacete, wisconsin, spain</td><td>26.0</td><td>albacete</td><td>wisconsin</td><td>spain</td><td>2020-07-04T18:18:19.970+0000</td><td>193428</td><td>5.0</td></tr><tr><td>12</td><td>fort bragg, california, usa</td><td>34.74389988072476</td><td>fort bragg</td><td>california</td><td>usa</td><td>2020-07-23T04:19:17.666+0000</td><td>196326</td><td>0.0</td></tr><tr><td>14</td><td>mediapolis, iowa, usa</td><td>34.74389988072476</td><td>mediapolis</td><td>iowa</td><td>usa</td><td>2020-03-11T14:45:24.762+0000</td><td>196414</td><td>0.0</td></tr><tr><td>16</td><td>albuquerque, new mexico, usa</td><td>34.74389988072476</td><td>albuquerque</td><td>new mexico</td><td>usa</td><td>2020-02-14T18:14:31.964+0000</td><td>384041</td><td>0.0</td></tr><tr><td>17</td><td>chesapeake, virginia, usa</td><td>34.74389988072476</td><td>chesapeake</td><td>virginia</td><td>usa</td><td>2020-03-29T06:12:18.883+0000</td><td>426729</td><td>0.0</td></tr><tr><td>19</td><td>weston, ,</td><td>14.0</td><td>weston</td><td>,</td><td>null</td><td>2021-05-23T16:16:05.804+0000</td><td>450331</td><td>414.0</td></tr><tr><td>20</td><td>langhorne, pennsylvania, usa</td><td>19.0</td><td>langhorne</td><td>pennsylvania</td><td>usa</td><td>2020-03-28T01:53:40.955+0000</td><td>451548</td><td>0.0</td></tr><tr><td>22</td><td>erfurt, thueringen, germany</td><td>34.74389988072476</td><td>erfurt</td><td>thueringen</td><td>germany</td><td>2021-01-05T13:13:26.804+0000</td><td>453091</td><td>2.0</td></tr><tr><td>23</td><td>philadelphia, pennsylvania, usa</td><td>34.74389988072476</td><td>philadelphia</td><td>pennsylvania</td><td>usa</td><td>2022-08-09T15:05:08.559+0000</td><td>453111</td><td>0.0</td></tr><tr><td>26</td><td>bellevue, washington, usa</td><td>34.74389988072476</td><td>bellevue</td><td>washington</td><td>usa</td><td>2020-03-03T17:30:29.355+0000</td><td>454017</td><td>0.0</td></tr><tr><td>32</td><td>portland, oregon, usa</td><td>34.74389988072476</td><td>portland</td><td>oregon</td><td>usa</td><td>2020-03-02T17:26:28.222+0000</td><td>489652</td><td>0.0</td></tr><tr><td>36</td><td>montreal, quebec, canada</td><td>24.0</td><td>montreal</td><td>quebec</td><td>canada</td><td>2020-01-05T20:25:16.731+0000</td><td>492565</td><td>1.0</td></tr><tr><td>39</td><td>cary, north carolina, usa</td><td>34.74389988072476</td><td>cary</td><td>north carolina</td><td>usa</td><td>2020-03-22T18:57:19.960+0000</td><td>492612</td><td>0.0</td></tr><tr><td>42</td><td>appleton, wisconsin, usa</td><td>17.0</td><td>appleton</td><td>wisconsin</td><td>usa</td><td>2020-09-11T18:58:57.186+0000</td><td>502306</td><td>0.0</td></tr><tr><td>44</td><td>black mountain, north carolina, usa</td><td>51.0</td><td>black mountain</td><td>north carolina</td><td>usa</td><td>2020-01-05T01:08:26.795+0000</td><td>507018</td><td>0.0</td></tr><tr><td>51</td><td>renton, washington, usa</td><td>34.0</td><td>renton</td><td>washington</td><td>usa</td><td>2020-09-16T03:24:41.147+0000</td><td>534923</td><td>0.0</td></tr><tr><td>53</td><td>tacoma, washington, usa</td><td>34.74389988072476</td><td>tacoma</td><td>washington</td><td>usa</td><td>2020-01-27T00:34:38.249+0000</td><td>544209</td><td> ...

# %%
# %sql
-- Feature #2: Bucketize user age (precomputed prior to Feast)
SELECT
  user_id,
  signup_date,
  CASE 
    WHEN age < 0 THEN -1
    WHEN age >= 0 AND age <= 10 THEN 0
    WHEN age > 10 AND age <= 20 THEN 1
    WHEN age > 20 AND age <= 30 THEN 2
    WHEN age > 30 AND age <= 40 THEN 3
    WHEN age > 40 AND age <= 50 THEN 4
    WHEN age > 50 AND age <= 60 THEN 5
    WHEN age > 60 AND age <= 70 THEN 6
    WHEN age > 70 AND age <= 80 THEN 7
    WHEN age > 80 AND age <= 90 THEN 8
    WHEN age > 90 AND age <= 100 THEN 9
    ELSE 10 
  END AS bucketedAge
FROM
  book_recsys_apply.users
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th
td>67544</td><td>0002005018</td><td>8</td><td>2022-08-19T22:17:44.554+0000</td></tr><tr><td>85526</td><td>0002005018</td><td>0</td><td>2021-03-31T07:40:07.129+0000</td></tr><tr><td>96054</td><td>0002005018</td><td>0</td><td>2022-12-15T01:23:46.267+0000</td></tr><tr><td>116866</td><td>0002005018</td><td>9</td><td>2022-10-03T14:47:45.018+0000</td></tr><tr><td>123629</td><td>0002005018</td><td>9</td><td>2021-10-07T01:11:34.382+0000</td></tr></tbody></table></div>

# %%
ratings_df = ratings.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:202: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass &#39;datetime64[ns]&#39; instead
#   series = series.astype(t, copy=False)
# </div>

# %% [markdown]
# ### 5a) Model v1: book language, country, bucketed user age

# %%
features_v1 = store.get_historical_features(
  entity_df=ratings_df, 
  features=store.get_feature_service("model_v1")
).to_spark_df()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:202: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass &#39;datetime64[ns]&#39; instead
#   series = series.astype(t, copy=False)
# Using rating_timestamp as the event timestamp. To specify a column explicitly, please name it event_timestamp.
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:382: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# </div>

# %%
transformationModel = pipeline.fit(features_v1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
features_v1.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user_id: long (nullable = true)
# -- isbn: string (nullable = true)
# -- rating: long (nullable = true)
# -- rating_timestamp: timestamp (nullable = true)
# -- Language: string (nullable = true)
# -- Category: string (nullable = true)
# -- country: string (nullable = true)
# -- bucketedAge: integer (nullable = true)
#
# </div>

# %%
# Run prior transformations
features_v1_transformed = transformationModel.transform(features_v1)
features_v1_transformed.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user_id: long (nullable = true)
# -- isbn: string (nullable = true)
# -- rating: long (nullable = true)
# -- rating_timestamp: timestamp (nullable = true)
# -- Language: string (nullable = true)
# -- Category: string (nullable = true)
# -- country: string (nullable = true)
# -- bucketedAge: integer (nullable = true)
# -- country_idx: double (nullable = false)
# -- Language_idx: double (nullable = false)
#
# </div>

# %%
# Prep training data for v1
features_v1_all = features_v1_transformed.toPandas()
train_v1_all = features_v1_all[features_v1_all["rating_timestamp"] <= "2022-01-01"]
train_Y = train_v1_all["rating"]
train_X = train_v1_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
test_v1_all = features_v1_all[features_v1_all["rating_timestamp"] > "2022-01-01"]
test_Y = test_v1_all["rating"]
test_X = test_v1_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:202: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass &#39;datetime64[ns]&#39; instead
#   series = series.astype(t, copy=False)
# </div>

# %%
xgb_v1 = xgb.XGBRegressor(objective='reg:squarederror', random_state=233)
 
# Fitting the model
xgb_v1.fit(train_X, train_Y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[98]: XGBRegressor(base_score=0.5, booster=&#39;gbtree&#39;, callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy=&#39;depthwise&#39;, importance_type=None,
#              interaction_constraints=&#39;&#39;, learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints=&#39;()&#39;, n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor=&#39;auto&#39;, random_state=233, ...)</div>

# %%
from sklearn.metrics import mean_squared_error as MSE

pred = xgb_v1.predict(test_X)
# RMSE Computation
rmse = np.sqrt(MSE(test_Y, pred))
print("RMSE : % f" %(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE :  3.571208
# </div>

# %% [markdown]
# ### 5b) Model v2: Add in avg book rating

# %%
features_v2 = store.get_historical_features(
  entity_df=ratings_df, 
  features=store.get_feature_service("model_v2")
).to_spark_df()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:202: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass &#39;datetime64[ns]&#39; instead
#   series = series.astype(t, copy=False)
# Using rating_timestamp as the event timestamp. To specify a column explicitly, please name it event_timestamp.
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:382: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# </div>

# %%
# Run prior transformations
features_v2_transformed = transformationModel.transform(features_v2)
features_v2_transformed.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user_id: long (nullable = true)
# -- isbn: string (nullable = true)
# -- rating: long (nullable = true)
# -- rating_timestamp: timestamp (nullable = true)
# -- Language: string (nullable = true)
# -- Category: string (nullable = true)
# -- country: string (nullable = true)
# -- bucketedAge: integer (nullable = true)
# -- avg_yr_user_rating: double (nullable = true)
# -- count_yr_user_rating: long (nullable = true)
# -- country_idx: double (nullable = false)
# -- Language_idx: double (nullable = false)
#
# </div>

# %%
# Prep training data for v2
features_v2_all = features_v2_transformed.toPandas()
train_v2_all = features_v2_all[features_v2_all["rating_timestamp"] <= "2022-01-01"]
train_v2_Y = train_v2_all["rating"]
train_v2_X = train_v2_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
test_v2_all = features_v2_all[features_v2_all["rating_timestamp"] > "2022-01-01"]
test_v2_Y = test_v2_all["rating"]
test_v2_X = test_v2_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:202: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass &#39;datetime64[ns]&#39; instead
#   series = series.astype(t, copy=False)
# </div>

# %%
xgb_v2 = xgb.XGBRegressor(objective='reg:squarederror', random_state=233)
 
# Fitting the model
xgb_v2.fit(train_v2_X, train_v2_Y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[103]: XGBRegressor(base_score=0.5, booster=&#39;gbtree&#39;, callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy=&#39;depthwise&#39;, importance_type=None,
#              interaction_constraints=&#39;&#39;, learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints=&#39;()&#39;, n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor=&#39;auto&#39;, random_state=233, ...)</div>

# %%
from sklearn.metrics import mean_squared_error as MSE

pred = xgb_v2.predict(test_v2_X)
# RMSE Computation
rmse = np.sqrt(MSE(test_v2_Y, pred))
print("RMSE : % f" %(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE :  2.576914
# </div>

# %% [markdown]
# ### 5c) Model v3: Add in average user rating in last yr

# %%
features_v3 = store.get_historical_features(
  entity_df=ratings_df, 
  features=store.get_feature_service("model_v3")
).to_spark_df()
features_v3.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Using rating_timestamp as the event timestamp. To specify a column explicitly, please name it event_timestamp.
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:382: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# </div>

# %%
# Run prior transformations
features_v3_transformed = transformationModel.transform(features_v3)
features_v3_transformed.printSchema()

# Prep training data for v3
features_v3_all = features_v3_transformed.toPandas()
train_v3_all = features_v3_all[features_v3_all["rating_timestamp"] <= "2022-01-01"]
train_v3_Y = train_v3_all["rating"]
train_v3_X = train_v3_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
test_v3_all = features_v3_all[features_v3_all["rating_timestamp"] > "2022-01-01"]
test_v3_Y = test_v3_all["rating"]
test_v3_X = test_v3_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user_id: long (nullable = true)
# -- isbn: string (nullable = true)
# -- rating: long (nullable = true)
# -- rating_timestamp: timestamp (nullable = true)
# -- Language: string (nullable = true)
# -- Category: string (nullable = true)
# -- country: string (nullable = true)
# -- bucketedAge: integer (nullable = true)
# -- avg_yr_book_rating: double (nullable = true)
# -- count_yr_book_rating: long (nullable = true)
# -- avg_yr_user_rating: double (nullable = true)
# -- count_yr_user_rating: long (nullable = true)
# -- country_idx: double (nullable = false)
# -- Language_idx: double (nullable = false)
#
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:202: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass &#39;datetime64[ns]&#39; instead
#   series = series.astype(t, copy=False)
# </div>

# %%
xgb_v3 = xgb.XGBRegressor(objective='reg:squarederror', random_state=233)
 
# Fitting the model
xgb_v3.fit(train_v3_X, train_v3_Y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: XGBRegressor(base_score=0.5, booster=&#39;gbtree&#39;, callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy=&#39;depthwise&#39;, importance_type=None,
#              interaction_constraints=&#39;&#39;, learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints=&#39;()&#39;, n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor=&#39;auto&#39;, random_state=233, ...)</div>

# %%
from sklearn.metrics import mean_squared_error as MSE

pred = xgb_v3.predict(test_v3_X)
# RMSE Computation
rmse = np.sqrt(MSE(test_v3_Y, pred))
print("RMSE : % f" %(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE :  2.321369
# </div>

# %% [markdown]
# ### 5d) Model 4: Add average rating per book category

# %%
# To train a model, you need labeled events, and point in time correct features. Feast provides the features.
# Labeled events: historical log of user ratings
# 1) Pull in user + book + rating features in that you need to train your model
features_v4 = store.get_historical_features(
  entity_df=ratings_df, 
  features=store.get_feature_service("model_v4")
).to_spark_df()
features_v4.cache()

# Run prior transformations
features_v4_transformed = transformationModel.transform(features_v4)
features_v4_transformed.printSchema()

# Prep training data for v4
features_v4_all = features_v4_transformed.toPandas()
train_v4_all = features_v4_all[features_v4_all["rating_timestamp"] <= "2022-01-01"]
train_v4_Y = train_v4_all["rating"]
train_v4_X = train_v4_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
test_v4_all = features_v4_all[features_v4_all["rating_timestamp"] > "2022-01-01"]
test_v4_Y = test_v4_all["rating"]
test_v4_X = test_v4_all.drop(columns=["rating", "isbn", "rating_timestamp", "country", "Language", "Category"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Using rating_timestamp as the event timestamp. To specify a column explicitly, please name it event_timestamp.
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:382: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# root
# -- user_id: long (nullable = true)
# -- isbn: string (nullable = true)
# -- rating: long (nullable = true)
# -- rating_timestamp: timestamp (nullable = true)
# -- Language: string (nullable = true)
# -- Category: string (nullable = true)
# -- country: string (nullable = true)
# -- avg_yr_book_rating: double (nullable = true)
# -- count_yr_book_rating: long (nullable = true)
# -- avg_yr_user_rating: double (nullable = true)
# -- count_yr_user_rating: long (nullable = true)
# -- avg_yr_category_rating: double (nullable = true)
# -- count_yr_category_rating: long (nullable = true)
# -- country_idx: double (nullable = false)
# -- Language_idx: double (nullable = false)
#
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:202: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass &#39;datetime64[ns]&#39; instead
#   series = series.astype(t, copy=False)
# </div>

# %%
# 2) For an incoming transaction, pull the latest feature values for the associated user
# Note: Feast decoupled, so caller doesn't think about whether to pull this from a batch or streaming source
feature_vector = store.get_online_features(
    features=store.get_feature_service("model_v4"),
    entity_rows=[
        {
            "user_id": "213915",
            "isbn": "0061099686"
        }
    ],
).to_dict()
# model.predict(feature_vector)

def print_online_features(feature_vector):
    for key, value in sorted(feature_vector.items()):
        print(key, " : ", value)

print_online_features(feature_vector)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Category  :  [&#39;Fiction&#39;]
# Language  :  [&#39;en&#39;]
# avg_day_user_rating  :  [0.0]
# avg_yr_book_rating  :  [0.25]
# avg_yr_category_rating  :  [2.8445375460008386]
# avg_yr_user_rating  :  [1.03125]
# count_day_user_rating  :  [1]
# count_yr_book_rating  :  [12]
# count_yr_category_rating  :  [343472]
# count_yr_user_rating  :  [32]
# country  :  [&#39;united kingdom&#39;]
# isbn  :  [&#39;0061099686&#39;]
# user_id  :  [213915]
# </div>

# %%
xgb_v4 = xgb.XGBRegressor(objective='reg:squarederror', random_state=233)
 
# Fitting the model
xgb_v4.fit(train_v4_X, train_v4_Y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[56]: XGBRegressor(base_score=0.5, booster=&#39;gbtree&#39;, callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy=&#39;depthwise&#39;, importance_type=None,
#              interaction_constraints=&#39;&#39;, learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints=&#39;()&#39;, n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor=&#39;auto&#39;, random_state=233, ...)</div>

# %%
from sklearn.metrics import mean_squared_error as MSE

pred = xgb_v4.predict(test_v4_X)
# RMSE Computation
rmse = np.sqrt(MSE(test_v4_Y, pred))
print("RMSE : % f" %(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE :  2.362633
# </div>

# %% [markdown]
# ## 6) Moving the latest feature values into a low latency store
# We do this by materializing batch precomputed features and also pushing stream precomputed features

# %%
from datetime import datetime
store.materialize(
  start_date=datetime(1900,4,20), 
  end_date=datetime(2022,4,21), 
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Materializing <span class="ansi-green-intense-fg ansi-bold">7</span> feature views from <span class="ansi-green-intense-fg ansi-bold">1900-04-20 00:00:00+00:00</span> to <span class="ansi-green-intense-fg ansi-bold">2022-04-21 00:00:00+00:00</span> into the <span class="ansi-green-intense-fg ansi-bold">dynamodb</span> online store.
#
# <span class="ansi-green-intense-fg ansi-bold">book_features</span>:
# Pulling latest features from spark offline store
# <span class="ansi-green-intense-fg ansi-bold">book_agg_rating_features</span>:
# Pulling latest features from spark offline store
# <span class="ansi-green-intense-fg ansi-bold">user_agg_rating_features</span>:
# Pulling latest features from spark offline store
# <span class="ansi-green-intense-fg ansi-bold">user_features</span>:
# Pulling latest features from spark offline store
# <span class="ansi-green-intense-fg ansi-bold">agg_user_features_1d</span>:
# Pulling latest features from spark offline store
# <span class="ansi-green-intense-fg ansi-bold">user_age_features</span>:
# Pulling latest features from spark offline store
# <span class="ansi-green-intense-fg ansi-bold">avg_book_category_rating_features</span>:
# Pulling latest features from spark offline store
# </div>

# %% [markdown]
# ## Computing + pushing streaming feature values

# %%
def raw_data_deserialization(df):
    from pyspark.sql.functions import col, from_json, from_utc_timestamp, when
    from pyspark.sql.types import StructType, StructField, StringType, DoubleType, TimestampType, BooleanType, IntegerType

    payload_schema = StructType([
        StructField('user_id', StringType(), False),
        StructField('isbn', StringType(), False),
        StructField('rating_timestamp', StringType(), False),
        StructField('rating', StringType(), False),
    ])

    return (
        df.selectExpr('cast (data as STRING) jsonData')
            .select(from_json('jsonData', payload_schema).alias('payload'))
            .select(
            col('payload.user_id').alias('user_id'),
            col('payload.isbn').alias('isbn'),
            from_utc_timestamp('payload.rating_timestamp', 'UTC').alias('rating_timestamp'),
            col('payload.rating').cast('long').alias('rating'),
175+0000</td><td>0</td></tr><tr><td>191707</td><td>3442215382</td><td>2022-12-06T05:53:42.175+0000</td><td>0</td></tr><tr><td>35857</td><td>0836220730</td><td>2022-12-06T05:53:42.175+0000</td><td>0</td></tr><tr><td>20172</td><td>0440401801</td><td>2022-12-06T05:53:42.175+0000</td><td>8</td></tr><tr><td>250330</td><td>0671865609</td><td>2022-12-06T05:53:42.175+0000</td><td>0</td></tr><tr><td>200312</td><td>0684842483</td><td>2022-12-06T05:53:42.175+0000</td><td>0</td></tr><tr><td>155014</td><td>0064400581</td><td>2022-12-06T05:53:42.175+0000</td><td>8</td></tr><tr><td>27169</td><td>0061092533</td><td>2022-12-06T05:53:51.236+0000</td><td>8</td></tr><tr><td>79215</td><td>0743204840</td><td>2022-12-06T05:53:51.236+0000</td><td>0</td></tr><tr><td>57148</td><td>0971880107</td><td>2022-12-06T05:53:51.236+0000</td><td>1</td></tr><tr><td>217318</td><td>0440235057</td><td>2022-12-06T05:53:51.236+0000</td><td>5</td></tr><tr><td>91692</td><td>0425185249</td><td>2022-12-06T05:53:51.236+0000</td><td>0</td></tr><tr><td>183673</td><td>0786861347</td><td>2022-12-06T05:53:51.236+0000</td><td>6</td></tr><tr><td>123981</td><td>0061006742</td><td>2022-12-06T05:53:51.236+0000</td><td>0</td></tr><tr><td>41757</td><td>0385249543</td><td>2022-12-06T05:53:51.236+0000</td><td>0</td></tr><tr><td>240541</td><td>0140195831</td><td>2022-12-06T05:53:51.236+0000</td><td>9</td></tr><tr><td>168387</td><td>0743216024</td><td>2022-12-06T05:53:51.236+0000</td><td>0</td></tr><tr><td>189835</td><td>0375756809</td><td>2022-12-06T05:54:01.308+0000</td><td>5</td></tr><tr><td>258690</td><td>0553281976</td><td>2022-12-06T05:54:01.308+0000</td><td>0</td></tr><tr><td>189835</td><td>0064400735 ...

# %%
from pyspark.sql.functions import *
import pandas as pd

# 2) Aggregate feature values
stream_agg = (
  ratings_stream
    .groupBy(
      "user_id", 
      window(timeColumn="rating_timestamp", windowDuration="1 day", slideDuration="10 minutes")
    )
    .agg(
        count("rating").alias("count_day_user_rating"),
        avg("rating").alias("avg_day_user_rating")
    )
    .select(
      "user_id", 
      col("window.end").alias("rating_timestamp"), 
      "count_day_user_rating", 
      "avg_day_user_rating"
    )
)

# 3) Push transformed features into Feast
from feast import FeatureStore
store = FeatureStore(config=repo_config)

def send_to_feast(df, epoch):
    pandas_df: pd.DataFrame = df.toPandas()
    if pandas_df.empty:
        return
    
    if "timestamp" in pandas_df:
        # Filter out only for the latest window for the user_id
        pandas_df = pandas_df.sort_values(by=["user_id","rating_timestamp"], ascending=False).groupby("user_id").nth(-1)
        store.push("agg_user_features_1d_source", pandas_df)

# 4) Launch streaming job to do all the above
query = (
    stream_agg
        .writeStream
        .outputMode("append") 
        .option("checkpointLocation", "/tmp/feast-book-recsys-workshop/")
        .trigger(processingTime="30 seconds")
        .foreachBatch(send_to_feast)
        .start()
)

# 5) (not shown) Orchestrate this job so it's self-healing. Monitor to ensure features land in Feast.
query.awaitTermination(timeout=30)
query.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
